# %%
import numpy as np

# %%
P = np.array([[0.7,0.2,0.1],[0.4,0.6,0],[0,0.9,0.1]])

# %%
eigvals, eigvecs = np.linalg.eig(P)

# %%
# Out:
# [[ 0.40414519+0.j         -0.03694459-0.02742424j -0.01847229+0.01371212j]
#  [ 0.23094011+0.j          0.06333358+0.10969697j  0.        +0.j        ]
#  [ 0.        +0.j          0.8550033 +0.j          0.09500037+0.j        ]]

# %%
1+3/4+1/9
# Out:
# 1.8611111111111112
